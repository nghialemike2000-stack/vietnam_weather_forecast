# %% [markdown]
# # SECTION 0 — ADD ROOT PATH

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent

sys.path.append(
    str(PROJECT_ROOT)
)

print(PROJECT_ROOT)
# Out:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline

# %% [markdown]
# # SECTION 1 — Import

# %%
from pathlib import Path

import pandas as pd

from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from utils.data_loader import (
    DATA_PROVINCES,
    load_province_data
)

from utils.feature_engineering import (
    prepare_train_test_data,
)

from utils.evaluation import (
    evaluate_model,
    print_report,
    create_result_row,
    create_results_dataframe,
    rank_models
)

from utils.save_model import (
    save_complete_model_package
)

# %% [markdown]
# # SECTION 2 — Config

# %%
LOOKBACKS = [3, 5, 7, 10, 15, 30]

FORECAST_HORIZONS = [7]

ALL_RESULTS = []

# %% [markdown]
# # SECTION 3 — LOAD ONE PROVINCE

# %%
province_name = "Ha_Noi"

df = load_province_data(
    province_name
)

print(df.head())
print(df.shape)
# Out:
#         date destination  latitude  longitude  temp  humidity  wind_speed  \
# 0 2020-01-01      Ha_Noi   21.0285   105.8542  20.0        88         9.2
# 1 2020-01-02      Ha_Noi   21.0285   105.8542  21.2        84        15.0
# 2 2020-01-03      Ha_Noi   21.0285   105.8542  21.5        87        16.3
# 3 2020-01-04      Ha_Noi   21.0285   105.8542  21.2        88        18.1
# 4 2020-01-05      Ha_Noi   21.0285   105.8542  21.5        86        18.7
#
#    cloud_cover  pressure  rain
# 0           83    1021.4     1
# 1           75    1019.8     1
# 2           82    1017.9     1
# 3           77    1016.0     1
# 4           80    1014.8     1
# (2324, 10)

# %% [markdown]
# # SECTION 4 — PREPARE DATA

# %%
lookback = 7
forecast_horizon = 1

(
    X_train,
    X_test,
    y_train,
    y_test,
    train_df,
    test_df
) = prepare_train_test_data(
    df=df,
    lookback=lookback,
    forecast_horizon=forecast_horizon
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (2185, 35)
# (131, 35)

# %% [markdown]
# # SECTION 5 — CREATE MODEL

# %%
model = Pipeline([

    

    (
            "classifier",
        RandomForestClassifier(
            n_estimators=200,
            max_depth=10,
            random_state=42,
            class_weight="balanced"
        )
    )
])

# %% [markdown]
# # SECTION 6 — TRAIN MODEL

# %%
model.fit(
    X_train,
    y_train
)

print("Training completed.")
# Out:
# Training completed.

# %% [markdown]
# # SECTION 7 — PREDICT

# %%
y_pred = model.predict(
    X_test
)

y_prob = model.predict_proba(
    X_test
)[:, 1]

# %% [markdown]
# # SECTION 8 — EVALUATE

# %%
metrics = evaluate_model(
    y_test,
    y_pred,
    y_prob
)

print(metrics)

print_report(
    y_test,
    y_pred
)
# Out:
# {'accuracy': 0.7251908396946565, 'precision': 0.8, 'recall': 0.8333333333333334, 'f1': 0.8163265306122449, 'roc_auc': 0.6809523809523811}
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.43      0.45        35
#          1.0       0.80      0.83      0.82        96
#
#     accuracy                           0.73       131
#    macro avg       0.64      0.63      0.64       131
# weighted avg       0.72      0.73      0.72       131

# %% [markdown]
# # SECTION 9 — SAVE SINGLE RESULT

# %%
result_row = create_result_row(
    province=province_name,
    lookback=lookback,
    forecast_horizon=forecast_horizon,
    metrics=metrics
)

print(result_row)
# Out:
# {'province': 'Ha_Noi', 'forecast_horizon': 1, 'lookback': 7, 'accuracy': 0.7251908396946565, 'precision': 0.8, 'recall': 0.8333333333333334, 'f1': 0.8163265306122449, 'roc_auc': 0.6809523809523811}

# %% [markdown]
# # SECTION 10 — LOOP LOOKBACKS

# %%
province_results = []

trained_models = {}
for forecast_horizon in FORECAST_HORIZONS:

    print("\n")
    print("#" * 70)
    print(
        f"FORECAST HORIZON = "
        f"{forecast_horizon}"
    )
    print("#" * 70)
    for lookback in LOOKBACKS:

        print("\n")
        print("=" * 60)
        print(f"LOOKBACK = {lookback}")
        print("=" * 60)

        (
            X_train,
            X_test,
            y_train,
            y_test,
            train_df,
            test_df
        ) = prepare_train_test_data(
            df=df,
            lookback=lookback,
            forecast_horizon=forecast_horizon
        )

        model = Pipeline([

            

            (
                "classifier",
                RandomForestClassifier(
                    n_estimators=200,
                    max_depth=10,
                    random_state=42,
                    class_weight="balanced"
                )
            )
        ])

        model.fit(
            X_train,
            y_train
        )

        y_pred = model.predict(
            X_test
        )

        y_prob = model.predict_proba(
            X_test
        )[:, 1]

        metrics = evaluate_model(
            y_test,
            y_pred,
            y_prob
        )

        result_row = create_result_row(
            province=province_name,
            lookback=lookback,
            forecast_horizon=forecast_horizon,
            metrics=metrics
        )

        province_results.append(
            result_row
        )

        trained_models[
            (
                lookback,
                forecast_horizon
            )
        ] = {
            "model": model,
            "metrics": metrics
        }
# Out:
# ######################################################################
# FORECAST HORIZON = 7
# ######################################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================

# %% [markdown]
# # SECTION 11 — RANK MODELS

# %%
province_results_df = (
    create_results_dataframe(
        province_results
    )
)

ranked_df = rank_models(
    province_results_df
)

ranked_df.head(3)
# Out:
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0   Ha_Noi                 7        30     0.584   0.727273  0.695652
# 1   Ha_Noi                 7        10     0.560   0.717647  0.663043
# 2   Ha_Noi                 7        15     0.552   0.709302  0.663043
#
#          f1   roc_auc
# 0  0.711111  0.465415
# 1  0.689266  0.472661
# 2  0.685393  0.465086

# %% [markdown]
# # SECTION 12 — SAVE TOP MODELS

# %%
# ======================================
# GET TOP 3
# ======================================

top_3_models = ranked_df.head(3)

for rank, (_, row) in enumerate(
    top_3_models.iterrows(),
    start=1
):

    # ==================================
    # GET LOOKBACK
    # ==================================

    lookback = int(
        row["lookback"]
    )

    # ==================================
    # GET FORECAST HORIZON
    # ==================================

    forecast_horizon = int(
        row["forecast_horizon"]
    )

    # ==================================
    # LOAD TRAINED MODEL
    # ==================================

    model = trained_models[
        (
            lookback,
            forecast_horizon
        )
    ]["model"]

    # ==================================
    # LOAD METRICS
    # ==================================

    metrics = trained_models[
        (
            lookback,
            forecast_horizon
        )
    ]["metrics"]

    # ==================================
    # CREATE METADATA
    # ==================================

    metadata = {

        "province":
            province_name,

        "model_rank":
            rank,

        "algorithm":
            "RandomForest",

        "lookback":
            lookback,

        "forecast_horizon":
            forecast_horizon,

        "accuracy":
            float(metrics["accuracy"]),

        "precision":
            float(metrics["precision"]),

        "recall":
            float(metrics["recall"]),

        "f1":
            float(metrics["f1"]),

        "roc_auc":
            float(metrics["roc_auc"])
    }

    # ==================================
    # SAVE MODEL PACKAGE
    # ==================================

    save_complete_model_package(

        algorithm_name=
            "RandomForest",

        province_name=
            province_name,

        forecast_horizon=
            forecast_horizon,

        model_rank=
            rank,

        model=
            model,

        metadata=
            metadata
    )

    print(
        f"\nSaved TOP {rank} | "
        f"Lookback={lookback} | "
        f"Horizon={forecast_horizon}"
    )
# Out:
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Noi\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Noi\horizon_7\model_2
#
# Saved TOP 2 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Noi\horizon_7\model_3
#
# Saved TOP 3 | Lookback=15 | Horizon=7

# %% [markdown]
# # SECTION 13 — LOOP ALL PROVINCES

# %%
ALL_RESULTS = []

for province_name in DATA_PROVINCES:

    print("\n")
    print("#" * 70)
    print(f"PROVINCE: {province_name}")
    print("#" * 70)

    # ======================================
    # LOAD DATA
    # ======================================

    df = load_province_data(
        province_name
    )

    province_results = []

    trained_models = {}

    # ======================================
    # LOOP FORECAST HORIZONS
    # ======================================

    for forecast_horizon in FORECAST_HORIZONS:

        print("\n")
        print("#" * 60)
        print(
            f"FORECAST HORIZON = "
            f"{forecast_horizon}"
        )
        print("#" * 60)

        # ==================================
        # LOOP LOOKBACKS
        # ==================================

        for lookback in LOOKBACKS:

            print("\n")
            print("=" * 60)
            print(f"LOOKBACK = {lookback}")
            print("=" * 60)

            (
                X_train,
                X_test,
                y_train,
                y_test,
                train_df,
                test_df
            ) = prepare_train_test_data(
                df=df,
                lookback=lookback,
                forecast_horizon=forecast_horizon
            )

            # ==============================
            # CREATE MODEL
            # ==============================

            model = Pipeline([

                
                (
                    "classifier",
                    RandomForestClassifier(
                        n_estimators=200,
                        max_depth=10,
                        random_state=42,
                        class_weight="balanced"
                    )
                )
            ])

            # ==============================
            # TRAIN
            # ==============================

            model.fit(
                X_train,
                y_train
            )

            # ==============================
            # PREDICT
            # ==============================

            y_pred = model.predict(
                X_test
            )

            y_prob = model.predict_proba(
                X_test
            )[:, 1]

            # ==============================
            # EVALUATE
            # ==============================

            metrics = evaluate_model(
                y_test,
                y_pred,
                y_prob
            )

            # ==============================
            # RESULT ROW
            # ==============================

            result_row = create_result_row(
                province=province_name,
                lookback=lookback,
                forecast_horizon=forecast_horizon,
                metrics=metrics
            )

            province_results.append(
                result_row
            )

            ALL_RESULTS.append(
                result_row
            )

            # ==============================
            # STORE MODEL
            # ==============================

            trained_models[
                (
                    lookback,
                    forecast_horizon
                )
            ] = {

                "model":
                    model,

                "metrics":
                    metrics
            }

    # ======================================
    # CREATE RESULTS DATAFRAME
    # ======================================

    province_results_df = (
        create_results_dataframe(
            province_results
        )
    )

    # ======================================
    # RANK MODELS
    # ======================================

    ranked_df = rank_models(
        province_results_df
    )

    print("\n")
    print("=" * 60)
    print("TOP 3 MODELS")
    print("=" * 60)

    print(
        ranked_df.head(3)
    )

    # ======================================
    # SAVE TOP 3 MODELS
    # ======================================

    top_3_models = ranked_df.head(3)

    for rank, (_, row) in enumerate(
        top_3_models.iterrows(),
        start=1
    ):

        lookback = int(
            row["lookback"]
        )

        forecast_horizon = int(
            row["forecast_horizon"]
        )

        # ==================================
        # LOAD MODEL
        # ==================================

        model = trained_models[
            (
                lookback,
                forecast_horizon
            )
        ]["model"]

        # ==================================
        # LOAD METRICS
        # ==================================

        metrics = trained_models[
            (
                lookback,
                forecast_horizon
            )
        ]["metrics"]

        # ==================================
        # METADATA
        # ==================================

        metadata = {

            "province":
                province_name,

            "model_rank":
                rank,

            "algorithm":
                "RandomForest",

            "lookback":
                lookback,

            "forecast_horizon":
                forecast_horizon,

            "accuracy":
                float(metrics["accuracy"]),

            "precision":
                float(metrics["precision"]),

            "recall":
                float(metrics["recall"]),

            "f1":
                float(metrics["f1"]),

            "roc_auc":
                float(metrics["roc_auc"])
        }

        # ==================================
        # SAVE MODEL
        # ==================================

        save_complete_model_package(

            algorithm_name=
                "RandomForest",

            province_name=
                province_name,

            forecast_horizon=
                forecast_horizon,

            model_rank=
                rank,

            model=
                model,

            metadata=
                metadata
        )

        print(
            f"\nSaved TOP {rank} | "
            f"Lookback={lookback} | "
            f"Horizon={forecast_horizon}"
        )

    print("\n")
    print("=" * 60)
    print(f"FINISHED: {province_name}")
    print("=" * 60)
# Out:
# ######################################################################
# PROVINCE: An_Giang
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  An_Giang                 7         3     0.648   0.666667  0.625000
# 1  An_Giang                 7        15     0.656   0.714286  0.546875
# 2  An_Giang                 7         5     0.640   0.686275  0.546875
#
#          f1   roc_auc
# 0  0.645161  0.678791
# 1  0.619469  0.666240
# 2  0.608696  0.670082
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\An_Giang\horizon_7\model_1
#
# Saved TOP 1 | Lookback=3 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\An_Giang\horizon_7\model_2
#
# Saved TOP 2 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\An_Giang\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: An_Giang
# ============================================================
#
#
# ######################################################################
# PROVINCE: Bac_Ninh
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Bac_Ninh                 7        30     0.608   0.726316  0.750000
# 1  Bac_Ninh                 7        15     0.600   0.718750  0.750000
# 2  Bac_Ninh                 7        10     0.584   0.722222  0.706522
#
#          f1  roc_auc
# 0  0.737968  0.45751
# 1  0.734043  0.45224
# 2  0.714286  0.45191
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Bac_Ninh\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Bac_Ninh\horizon_7\model_2
#
# Saved TOP 2 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Bac_Ninh\horizon_7\model_3
#
# Saved TOP 3 | Lookback=10 | Horizon=7
#
#
# ============================================================
# FINISHED: Bac_Ninh
# ============================================================
#
#
# ######################################################################
# PROVINCE: Can_Tho
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Can_Tho                 7        30     0.544   0.619718  0.594595
# 1  Can_Tho                 7        15     0.576   0.677966  0.540541
# 2  Can_Tho                 7         7     0.568   0.678571  0.513514
#
#          f1   roc_auc
# 0  0.606897  0.563858
# 1  0.601504  0.616057
# 2  0.584615  0.588500
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Can_Tho\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Can_Tho\horizon_7\model_2
#
# Saved TOP 2 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Can_Tho\horizon_7\model_3
#
# Saved TOP 3 | Lookback=7 | Horizon=7
#
#
# ============================================================
# FINISHED: Can_Tho
# ============================================================
#
#
# ######################################################################
# PROVINCE: Cao_Bang
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Cao_Bang                 7        30      0.64   0.702128  0.795181
# 1  Cao_Bang                 7         7      0.52   0.635294  0.650602
# 2  Cao_Bang                 7        15      0.52   0.641975  0.626506
#
#          f1   roc_auc
# 0  0.745763  0.531268
# 1  0.642857  0.366036
# 2  0.634146  0.443488
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Cao_Bang\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Cao_Bang\horizon_7\model_2
#
# Saved TOP 2 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Cao_Bang\horizon_7\model_3
#
# Saved TOP 3 | Lookback=15 | Horizon=7
#
#
# ============================================================
# FINISHED: Cao_Bang
# ============================================================
#
#
# ######################################################################
# PROVINCE: Ca_Mau
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0   Ca_Mau                 7        30     0.544   0.697674  0.659341
# 1   Ca_Mau                 7         7     0.568   0.784615  0.560440
# 2   Ca_Mau                 7         5     0.552   0.761194  0.560440
#
#          f1   roc_auc
# 0  0.677966  0.544926
# 1  0.653846  0.616031
# 2  0.645570  0.568843
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ca_Mau\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ca_Mau\horizon_7\model_2
#
# Saved TOP 2 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ca_Mau\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: Ca_Mau
# ============================================================
#
#
# ######################################################################
# PROVINCE: Dak_Lak
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Dak_Lak                 7         7     0.664   0.584906  0.607843
# 1  Dak_Lak                 7        10     0.648   0.568627  0.568627
# 2  Dak_Lak                 7        15     0.608   0.517857  0.568627
#
#          f1   roc_auc
# 0  0.596154  0.679120
# 1  0.568627  0.687599
# 2  0.542056  0.646264
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dak_Lak\horizon_7\model_1
#
# Saved TOP 1 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dak_Lak\horizon_7\model_2
#
# Saved TOP 2 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dak_Lak\horizon_7\model_3
#
# Saved TOP 3 | Lookback=15 | Horizon=7
#
#
# ============================================================
# FINISHED: Dak_Lak
# ============================================================
#
#
# ######################################################################
# PROVINCE: Da_Nang
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Da_Nang                 7        30     0.616   0.586538  0.924242
# 1  Da_Nang                 7        10     0.608   0.579439  0.939394
# 2  Da_Nang                 7         3     0.568   0.551724  0.969697
#
#          f1   roc_auc
# 0  0.717647  0.663842
# 1  0.716763  0.677709
# 2  0.703297  0.483821
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Da_Nang\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Da_Nang\horizon_7\model_2
#
# Saved TOP 2 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Da_Nang\horizon_7\model_3
#
# Saved TOP 3 | Lookback=3 | Horizon=7
#
#
# ============================================================
# FINISHED: Da_Nang
# ============================================================
#
#
# ######################################################################
# PROVINCE: Dien_Bien
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#     province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Dien_Bien                 7        15     0.640   0.704545  0.492063
# 1  Dien_Bien                 7        30     0.648   0.771429  0.428571
# 2  Dien_Bien                 7        10     0.600   0.638298  0.476190
#
#          f1   roc_auc
# 0  0.579439  0.662826
# 1  0.551020  0.652074
# 2  0.545455  0.623144
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dien_Bien\horizon_7\model_1
#
# Saved TOP 1 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dien_Bien\horizon_7\model_2
#
# Saved TOP 2 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dien_Bien\horizon_7\model_3
#
# Saved TOP 3 | Lookback=10 | Horizon=7
#
#
# ============================================================
# FINISHED: Dien_Bien
# ============================================================
#
#
# ######################################################################
# PROVINCE: Dong_Nai
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Dong_Nai                 7         5     0.720    0.76087  0.593220
# 1  Dong_Nai                 7         7     0.704    0.72000  0.610169
# 2  Dong_Nai                 7        10     0.688    0.70000  0.593220
#
#          f1   roc_auc
# 0  0.666667  0.724448
# 1  0.660550  0.728300
# 2  0.642202  0.724961
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dong_Nai\horizon_7\model_1
#
# Saved TOP 1 | Lookback=5 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dong_Nai\horizon_7\model_2
#
# Saved TOP 2 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dong_Nai\horizon_7\model_3
#
# Saved TOP 3 | Lookback=10 | Horizon=7
#
#
# ============================================================
# FINISHED: Dong_Nai
# ============================================================
#
#
# ######################################################################
# PROVINCE: Dong_Thap
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#     province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Dong_Thap                 7         7     0.584   0.692308  0.500000
# 1  Dong_Thap                 7         3     0.576   0.686275  0.486111
# 2  Dong_Thap                 7         5     0.552   0.648148  0.486111
#
#          f1   roc_auc
# 0  0.580645  0.633648
# 1  0.569106  0.615304
# 2  0.555556  0.588836
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dong_Thap\horizon_7\model_1
#
# Saved TOP 1 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dong_Thap\horizon_7\model_2
#
# Saved TOP 2 | Lookback=3 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Dong_Thap\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: Dong_Thap
# ============================================================
#
#
# ######################################################################
# PROVINCE: Gia_Lai
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Gia_Lai                 7        15     0.792   0.723404  0.723404
# 1  Gia_Lai                 7         5     0.792   0.769231  0.638298
# 2  Gia_Lai                 7        30     0.792   0.800000  0.595745
#
#          f1   roc_auc
# 0  0.723404  0.821604
# 1  0.697674  0.758865
# 2  0.682927  0.809602
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Gia_Lai\horizon_7\model_1
#
# Saved TOP 1 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Gia_Lai\horizon_7\model_2
#
# Saved TOP 2 | Lookback=5 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Gia_Lai\horizon_7\model_3
#
# Saved TOP 3 | Lookback=30 | Horizon=7
#
#
# ============================================================
# FINISHED: Gia_Lai
# ============================================================
#
#
# ######################################################################
# PROVINCE: Hai_Phong
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#     province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Hai_Phong                 7        10     0.504   0.647059  0.536585
# 1  Hai_Phong                 7        30     0.496   0.637681  0.536585
# 2  Hai_Phong                 7         5     0.464   0.631579  0.439024
#
#          f1   roc_auc
# 0  0.586667  0.514748
# 1  0.582781  0.527794
# 2  0.517986  0.469370
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hai_Phong\horizon_7\model_1
#
# Saved TOP 1 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hai_Phong\horizon_7\model_2
#
# Saved TOP 2 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hai_Phong\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: Hai_Phong
# ============================================================
#
#
# ######################################################################
# PROVINCE: Ha_Noi
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0   Ha_Noi                 7        30     0.584   0.727273  0.695652
# 1   Ha_Noi                 7        10     0.560   0.717647  0.663043
# 2   Ha_Noi                 7        15     0.552   0.709302  0.663043
#
#          f1   roc_auc
# 0  0.711111  0.465415
# 1  0.689266  0.472661
# 2  0.685393  0.465086
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Noi\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Noi\horizon_7\model_2
#
# Saved TOP 2 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Noi\horizon_7\model_3
#
# Saved TOP 3 | Lookback=15 | Horizon=7
#
#
# ============================================================
# FINISHED: Ha_Noi
# ============================================================
#
#
# ######################################################################
# PROVINCE: Ha_Tinh
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision   recall  \
# 0  Ha_Tinh                 7         3     0.480   0.495238  0.81250
# 1  Ha_Tinh                 7        15     0.440   0.471698  0.78125
# 2  Ha_Tinh                 7        30     0.424   0.460000  0.71875
#
#          f1   roc_auc
# 0  0.615385  0.454150
# 1  0.588235  0.417520
# 2  0.560976  0.400615
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Tinh\horizon_7\model_1
#
# Saved TOP 1 | Lookback=3 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Tinh\horizon_7\model_2
#
# Saved TOP 2 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ha_Tinh\horizon_7\model_3
#
# Saved TOP 3 | Lookback=30 | Horizon=7
#
#
# ============================================================
# FINISHED: Ha_Tinh
# ============================================================
#
#
# ######################################################################
# PROVINCE: Ho_Chi_Minh
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#       province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Ho_Chi_Minh                 7         7     0.656   0.714286  0.597015
# 1  Ho_Chi_Minh                 7        10     0.648   0.709091  0.582090
# 2  Ho_Chi_Minh                 7        15     0.632   0.690909  0.567164
#
#          f1   roc_auc
# 0  0.650407  0.690170
# 1  0.639344  0.673700
# 2  0.622951  0.670355
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ho_Chi_Minh\horizon_7\model_1
#
# Saved TOP 1 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ho_Chi_Minh\horizon_7\model_2
#
# Saved TOP 2 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Ho_Chi_Minh\horizon_7\model_3
#
# Saved TOP 3 | Lookback=15 | Horizon=7
#
#
# ============================================================
# FINISHED: Ho_Chi_Minh
# ============================================================
#
#
# ######################################################################
# PROVINCE: Hue
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0      Hue                 7         3     0.552   0.518868  0.916667
# 1      Hue                 7        15     0.584   0.544444  0.816667
# 2      Hue                 7         5     0.552   0.520833  0.833333
#
#          f1   roc_auc
# 0  0.662651  0.552051
# 1  0.653333  0.580769
# 2  0.641026  0.551282
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hue\horizon_7\model_1
#
# Saved TOP 1 | Lookback=3 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hue\horizon_7\model_2
#
# Saved TOP 2 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hue\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: Hue
# ============================================================
#
#
# ######################################################################
# PROVINCE: Hung_Yen
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Hung_Yen                 7        10     0.560   0.730769  0.626374
# 1  Hung_Yen                 7         7     0.488   0.675325  0.571429
# 2  Hung_Yen                 7        30     0.488   0.684932  0.549451
#
#          f1   roc_auc
# 0  0.674556  0.447641
# 1  0.619048  0.356496
# 2  0.609756  0.430511
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hung_Yen\horizon_7\model_1
#
# Saved TOP 1 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hung_Yen\horizon_7\model_2
#
# Saved TOP 2 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Hung_Yen\horizon_7\model_3
#
# Saved TOP 3 | Lookback=30 | Horizon=7
#
#
# ============================================================
# FINISHED: Hung_Yen
# ============================================================
#
#
# ######################################################################
# PROVINCE: Khanh_Hoa
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#     province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Khanh_Hoa                 7        15     0.568   0.534247  0.661017
# 1  Khanh_Hoa                 7        30     0.536   0.507692  0.559322
# 2  Khanh_Hoa                 7        10     0.520   0.492308  0.542373
#
#          f1   roc_auc
# 0  0.590909  0.570108
# 1  0.532258  0.576785
# 2  0.516129  0.515408
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Khanh_Hoa\horizon_7\model_1
#
# Saved TOP 1 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Khanh_Hoa\horizon_7\model_2
#
# Saved TOP 2 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Khanh_Hoa\horizon_7\model_3
#
# Saved TOP 3 | Lookback=10 | Horizon=7
#
#
# ============================================================
# FINISHED: Khanh_Hoa
# ============================================================
#
#
# ######################################################################
# PROVINCE: Lai_Chau
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Lai_Chau                 7        15      0.56   0.763636  0.500000
# 1  Lai_Chau                 7         5      0.52   0.714286  0.476190
# 2  Lai_Chau                 7        30      0.52   0.722222  0.464286
#
#          f1   roc_auc
# 0  0.604317  0.595528
# 1  0.571429  0.555168
# 2  0.565217  0.578688
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Lai_Chau\horizon_7\model_1
#
# Saved TOP 1 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Lai_Chau\horizon_7\model_2
#
# Saved TOP 2 | Lookback=5 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Lai_Chau\horizon_7\model_3
#
# Saved TOP 3 | Lookback=30 | Horizon=7
#
#
# ============================================================
# FINISHED: Lai_Chau
# ============================================================
#
#
# ######################################################################
# PROVINCE: Lam_Dong
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Lam_Dong                 7         5     0.656   0.765957  0.529412
# 1  Lam_Dong                 7        15     0.656   0.790698  0.500000
# 2  Lam_Dong                 7         7     0.632   0.729167  0.514706
#
#          f1   roc_auc
# 0  0.626087  0.671827
# 1  0.612613  0.704592
# 2  0.603448  0.689628
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Lam_Dong\horizon_7\model_1
#
# Saved TOP 1 | Lookback=5 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Lam_Dong\horizon_7\model_2
#
# Saved TOP 2 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Lam_Dong\horizon_7\model_3
#
# Saved TOP 3 | Lookback=7 | Horizon=7
#
#
# ============================================================
# FINISHED: Lam_Dong
# ============================================================
#
#
# ######################################################################
# PROVINCE: Lang_Son
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# ...
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#     province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Quang_Tri                 7        15     0.592   0.574074  0.925373
# 1  Quang_Tri                 7        10     0.592   0.578431  0.880597
# 2  Quang_Tri                 7         5     0.552   0.555556  0.820896
#
#          f1   roc_auc
# 0  0.708571  0.630983
# 1  0.698225  0.533453
# 2  0.662651  0.496397
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Quang_Tri\horizon_7\model_1
#
# Saved TOP 1 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Quang_Tri\horizon_7\model_2
#
# Saved TOP 2 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Quang_Tri\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: Quang_Tri
# ============================================================
#
#
# ######################################################################
# PROVINCE: Son_La
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#   province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0   Son_La                 7        15     0.552   0.714286  0.454545
# 1   Son_La                 7        30     0.544   0.717391  0.428571
# 2   Son_La                 7         7     0.504   0.674419  0.376623
#
#          f1   roc_auc
# 0  0.555556  0.588474
# 1  0.536585  0.631223
# 2  0.483333  0.543290
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Son_La\horizon_7\model_1
#
# Saved TOP 1 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Son_La\horizon_7\model_2
#
# Saved TOP 2 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Son_La\horizon_7\model_3
#
# Saved TOP 3 | Lookback=7 | Horizon=7
#
#
# ============================================================
# FINISHED: Son_La
# ============================================================
#
#
# ######################################################################
# PROVINCE: Tay_Ninh
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Tay_Ninh                 7        15     0.696   0.738095  0.534483
# 1  Tay_Ninh                 7        10     0.680   0.704545  0.534483
# 2  Tay_Ninh                 7         7     0.672   0.688889  0.534483
#
#          f1   roc_auc
# 0  0.620000  0.698919
# 1  0.607843  0.697633
# 2  0.601942  0.702265
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Tay_Ninh\horizon_7\model_1
#
# Saved TOP 1 | Lookback=15 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Tay_Ninh\horizon_7\model_2
#
# Saved TOP 2 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Tay_Ninh\horizon_7\model_3
#
# Saved TOP 3 | Lookback=7 | Horizon=7
#
#
# ============================================================
# FINISHED: Tay_Ninh
# ============================================================
#
#
# ######################################################################
# PROVINCE: Thai_Nguyen
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#       province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Thai_Nguyen                 7        10     0.696   0.757282  0.857143
# 1  Thai_Nguyen                 7        30     0.656   0.722222  0.857143
# 2  Thai_Nguyen                 7         5     0.640   0.725490  0.813187
#
#          f1   roc_auc
# 0  0.804124  0.495152
# 1  0.783920  0.470588
# 2  0.766839  0.447641
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Thai_Nguyen\horizon_7\model_1
#
# Saved TOP 1 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Thai_Nguyen\horizon_7\model_2
#
# Saved TOP 2 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Thai_Nguyen\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: Thai_Nguyen
# ============================================================
#
#
# ######################################################################
# PROVINCE: Thanh_Hoa
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#     province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Thanh_Hoa                 7        10     0.552   0.641975  0.658228
# 1  Thanh_Hoa                 7         5     0.536   0.629630  0.645570
# 2  Thanh_Hoa                 7         7     0.552   0.653333  0.620253
#
#          f1   roc_auc
# 0  0.650000  0.543203
# 1  0.637500  0.498899
# 2  0.636364  0.534397
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Thanh_Hoa\horizon_7\model_1
#
# Saved TOP 1 | Lookback=10 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Thanh_Hoa\horizon_7\model_2
#
# Saved TOP 2 | Lookback=5 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Thanh_Hoa\horizon_7\model_3
#
# Saved TOP 3 | Lookback=7 | Horizon=7
#
#
# ============================================================
# FINISHED: Thanh_Hoa
# ============================================================
#
#
# ######################################################################
# PROVINCE: Tuyen_Quang
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#       province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Tuyen_Quang                 7        30     0.576   0.712500  0.655172
# 1  Tuyen_Quang                 7         7     0.504   0.666667  0.574713
# 2  Tuyen_Quang                 7         5     0.480   0.644737  0.563218
#
#          f1   roc_auc
# 0  0.682635  0.493950
# 1  0.617284  0.432849
# 2  0.601227  0.393829
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Tuyen_Quang\horizon_7\model_1
#
# Saved TOP 1 | Lookback=30 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Tuyen_Quang\horizon_7\model_2
#
# Saved TOP 2 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Tuyen_Quang\horizon_7\model_3
#
# Saved TOP 3 | Lookback=5 | Horizon=7
#
#
# ============================================================
# FINISHED: Tuyen_Quang
# ============================================================
#
#
# ######################################################################
# PROVINCE: Vinh_Long
# ######################################################################
#
#
# ############################################################
# FORECAST HORIZON = 7
# ############################################################
#
#
# ============================================================
# LOOKBACK = 3
# ============================================================
#
#
# ============================================================
# LOOKBACK = 5
# ============================================================
#
#
# ============================================================
# LOOKBACK = 7
# ============================================================
#
#
# ============================================================
# LOOKBACK = 10
# ============================================================
#
#
# ============================================================
# LOOKBACK = 15
# ============================================================
#
#
# ============================================================
# LOOKBACK = 30
# ============================================================
#
#
# ============================================================
# TOP 3 MODELS
# ============================================================
#     province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  Vinh_Long                 7         7     0.568   0.596154  0.484375
# 1  Vinh_Long                 7         3     0.568   0.600000  0.468750
# 2  Vinh_Long                 7        10     0.552   0.574074  0.484375
#
#          f1   roc_auc
# 0  0.534483  0.604764
# 1  0.526316  0.600666
# 2  0.525424  0.615779
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Vinh_Long\horizon_7\model_1
#
# Saved TOP 1 | Lookback=7 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Vinh_Long\horizon_7\model_2
#
# Saved TOP 2 | Lookback=3 | Horizon=7
#
# Saved model to:
# D:\Bách khoa\Intelligence System\Weather Forecast Dashboard UI\backend\ml_pipeline\RandomForest\models\Vinh_Long\horizon_7\model_3
#
# Saved TOP 3 | Lookback=10 | Horizon=7
#
#
# ============================================================
# FINISHED: Vinh_Long
# ============================================================

# %% [markdown]
# # SECTION 14 — SAVE FINAL CSV

# %%
# ======================================
# CREATE FINAL RESULTS DATAFRAME
# ======================================

all_results_df = create_results_dataframe(
    ALL_RESULTS
)

# ======================================
# SORT RESULTS
# ======================================

all_results_df = all_results_df.sort_values(

    by=[
        "province",
        "forecast_horizon",
        "f1"
    ],

    ascending=[
        True,
        True,
        False
    ]
)

# ======================================
# CREATE SAVE DIRECTORY
# ======================================

save_path = Path(
    "results"
)

save_path.mkdir(
    parents=True,
    exist_ok=True
)

# ======================================
# SAVE CSV
# ======================================

csv_path = (
    save_path /
    f"random_forest_results_{FORECAST_HORIZONS[0]}.csv"
)

all_results_df.to_csv(
    csv_path,
    index=False
)

# ======================================
# PRINT SUMMARY
# ======================================

print("\n")
print("=" * 60)
print("TRAINING COMPLETED")
print("=" * 60)

print(
    f"Total Results: "
    f"{len(all_results_df)}"
)

print(
    f"Saved CSV:\n"
    f"{csv_path}"
)

print("\nTop Rows:")
print(
    all_results_df.head()
)
# Out:
# ============================================================
# TRAINING COMPLETED
# ============================================================
# Total Results: 204
# Saved CSV:
# results\random_forest_results_7.csv
#
# Top Rows:
#    province  forecast_horizon  lookback  accuracy  precision    recall  \
# 0  An_Giang                 7         3     0.648   0.666667  0.625000
# 4  An_Giang                 7        15     0.656   0.714286  0.546875
# 1  An_Giang                 7         5     0.640   0.686275  0.546875
# 2  An_Giang                 7         7     0.624   0.660377  0.546875
# 3  An_Giang                 7        10     0.640   0.702128  0.515625
#
#          f1   roc_auc
# 0  0.645161  0.678791
# 4  0.619469  0.666240
# 1  0.608696  0.670082
# 2  0.598291  0.688012
# 3  0.594595  0.695441
